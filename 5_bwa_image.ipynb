# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)


class ImageSpec(BaseModel):
    placeholder: str = Field(..., description="e.g. [[IMAGE_1]]")
    filename: str = Field(..., description="Save under images/, e.g. qkv_flow.png")
    alt: str
    caption: str
    prompt: str = Field(..., description="Prompt to send to the image model.")
    size: Literal["1024x1024", "1024x1536", "1536x1024"] = "1024x1024"
    quality: Literal["low", "medium", "high"] = "medium"


class GlobalImagePlan(BaseModel):
    md_with_placeholders: str
    images: List[ImageSpec] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)

    # reducer/image
    merged_md: str
    md_with_placeholders: str
    image_specs: List[dict]

    final: str


# -----------------------------
# 2) LLM
# -----------------------------
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily) 
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
# ============================================================
# 8) ReducerWithImages (subgraph)
#    merge_content -> decide_images -> generate_and_place_images
# ============================================================
def merge_content(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    merged_md = f"# {plan.blog_title}\n\n{body}\n"
    return {"merged_md": merged_md}


DECIDE_IMAGES_SYSTEM = """You are an expert technical editor.
Decide if images/diagrams are needed for THIS blog.

Rules:
- Max 3 images total.
- Each image must materially improve understanding (diagram/flow/table-like visual).
- Insert placeholders exactly: [[IMAGE_1]], [[IMAGE_2]], [[IMAGE_3]].
- If no images needed: md_with_placeholders must equal input and images=[].
- Avoid decorative images; prefer technical diagrams with short labels.
Return strictly GlobalImagePlan.
"""

def decide_images(state: State) -> dict:
    
    planner = llm.with_structured_output(GlobalImagePlan)
    merged_md = state["merged_md"]
    plan = state["plan"]
    assert plan is not None

    image_plan = planner.invoke(
        [
            SystemMessage(content=DECIDE_IMAGES_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Topic: {state['topic']}\n\n"
                    "Insert placeholders + propose image prompts.\n\n"
                    f"{merged_md}"
                )
            ),
        ]
    )

    return {
        "md_with_placeholders": image_plan.md_with_placeholders,
        "image_specs": [img.model_dump() for img in image_plan.images],
    }


def _gemini_generate_image_bytes(prompt: str) -> bytes:
    """
    Returns raw image bytes generated by Gemini.
    Requires: pip install google-genai
    Env var: GOOGLE_API_KEY
    """
    from google import genai
    from google.genai import types

    api_key = os.environ.get("GOOGLE_API_KEY")
    if not api_key:
        raise RuntimeError("GOOGLE_API_KEY is not set.")

    client = genai.Client(api_key=api_key)

    resp = client.models.generate_content(
        model="gemini-2.5-flash-image",
        contents=prompt,
        config=types.GenerateContentConfig(
            response_modalities=["IMAGE"],
            safety_settings=[
                types.SafetySetting(
                    category="HARM_CATEGORY_DANGEROUS_CONTENT",
                    threshold="BLOCK_ONLY_HIGH",
                )
            ],
        ),
    )

    # Depending on SDK version, parts may hang off resp.candidates[0].content.parts
    parts = getattr(resp, "parts", None)
    if not parts and getattr(resp, "candidates", None):
        try:
            parts = resp.candidates[0].content.parts
        except Exception:
            parts = None

    if not parts:
        raise RuntimeError("No image content returned (safety/quota/SDK change).")

    for part in parts:
        inline = getattr(part, "inline_data", None)
        if inline and getattr(inline, "data", None):
            return inline.data

    raise RuntimeError("No inline image bytes found in response.")


def generate_and_place_images(state: State) -> dict:

    plan = state["plan"]
    assert plan is not None

    md = state.get("md_with_placeholders") or state["merged_md"]
    image_specs = state.get("image_specs", []) or []

    # If no images requested, just write merged markdown
    if not image_specs:
        filename = f"{plan.blog_title}.md"
        Path(filename).write_text(md, encoding="utf-8")
        return {"final": md}

    images_dir = Path("images")
    images_dir.mkdir(exist_ok=True)

    for spec in image_specs:
        placeholder = spec["placeholder"]
        filename = spec["filename"]
        out_path = images_dir / filename

        # generate only if needed
        if not out_path.exists():
            try:
                img_bytes = _gemini_generate_image_bytes(spec["prompt"])
                out_path.write_bytes(img_bytes)
            except Exception as e:
                # graceful fallback: keep doc usable
                prompt_block = (
                    f"> **[IMAGE GENERATION FAILED]** {spec.get('caption','')}\n>\n"
                    f"> **Alt:** {spec.get('alt','')}\n>\n"
                    f"> **Prompt:** {spec.get('prompt','')}\n>\n"
                    f"> **Error:** {e}\n"
                )
                md = md.replace(placeholder, prompt_block)
                continue

        img_md = f"![{spec['alt']}](images/{filename})\n*{spec['caption']}*"
        md = md.replace(placeholder, img_md)

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(md, encoding="utf-8")
    return {"final": md}

# %%
# build reducer subgraph
reducer_graph = StateGraph(State)
reducer_graph.add_node("merge_content", merge_content)
reducer_graph.add_node("decide_images", decide_images)
reducer_graph.add_node("generate_and_place_images", generate_and_place_images)
reducer_graph.add_edge(START, "merge_content")
reducer_graph.add_edge("merge_content", "decide_images")
reducer_graph.add_edge("decide_images", "generate_and_place_images")
reducer_graph.add_edge("generate_and_place_images", END)
reducer_subgraph = reducer_graph.compile()

reducer_subgraph

# %%
# -----------------------------
# 9) Build main graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_subgraph)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,
            "sections": [],
            "merged_md": "",
            "md_with_placeholders": "",
            "image_specs": [],
            "final": "",
        }
    )

    return out

# %%
run("Self Attention in Transformer Architecture")
# Out:
# {'topic': 'Self Attention in Transformer Architecture',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Unpacking Self-Attention: The Core Mechanism of Transformer Architectures', audience='Developers, ML Engineers, Researchers', tone='Informative, Technical, Educational', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Introduction to Transformers and the Need for Attention', goal='Readers will understand the limitations of previous sequence models and why Transformers, particularly attention mechanisms, emerged as a solution.', bullets=['Briefly explain the limitations of Recurrent Neural Networks (RNNs) and Convolutional Neural Networks (CNNs) for capturing long-range dependencies in sequence data.', 'Introduce the Transformer architecture as a breakthrough for sequence-to-sequence tasks, emphasizing its parallelization capabilities.', 'Highlight the central role of attention mechanisms in overcoming the sequential bottlenecks of RNNs and enabling global context.', "Set the stage for a deep dive into Self-Attention as the foundational component of the Transformer's success."], target_words=180, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='The Intuition Behind Self-Attention', goal='Readers will grasp the fundamental idea of how Self-Attention allows a model to weigh the importance of different parts of the input sequence when processing each element.', bullets=["Explain the human analogy of 'paying attention' to relevant words in a sentence to understand context (e.g., pronoun resolution).", "Illustrate with a simple sentence example (e.g., 'The animal didn't cross the street because it was too tired.') to show how 'it' relates to 'animal'.", 'Introduce the Query, Key, and Value (QKV) triplet as conceptual vectors used to determine relevance and extract information from the input sequence.', 'Describe the high-level process: each word generates a query, compares it to keys of other words to get attention scores, and then sums their values based on these scores.'], target_words=220, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Mathematical Formulation of Scaled Dot-Product Self-Attention', goal='Readers will understand the detailed mathematical steps involved in calculating Scaled Dot-Product Self-Attention.', bullets=['Define the Query (Q), Key (K), and Value (V) matrices, explaining how they are derived from the input embeddings through linear transformations.', 'Detail the calculation of raw attention scores by performing a dot product between the Query matrix and the transpose of the Key matrix (QKᵀ).', 'Explain the importance of the scaling factor (dividing by the square root of the key dimension, √d_k) to prevent vanishing or exploding gradients.', 'Describe the application of the softmax function to normalize the attention scores, ensuring they sum to 1 and act as probabilities.', 'Show how the final output of the attention head is computed by multiplying the softmax-normalized scores with the Value matrix, resulting in a weighted sum of values.'], target_words=280, tags=['mathematics'], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Implementing Scaled Dot-Product Self-Attention (Minimal Working Example)', goal='Readers will be able to implement a basic Scaled Dot-Product Self-Attention module from scratch using a common deep learning framework.', bullets=['Provide a minimal Python code sketch using a framework like PyTorch or TensorFlow, demonstrating the linear projections for Q, K, and V from an input tensor.', 'Show the implementation of the dot product (matrix multiplication) between Q and Kᵀ, followed by the scaling operation.', 'Implement the softmax function applied to the scaled attention scores along the appropriate dimension.', 'Demonstrate the final matrix multiplication of the attention weights with the Value matrix to produce the attention output.', 'Include a small example input tensor and print the output shape ...
#  'sections': [(1,
#    "## Introduction to Transformers and the Need for Attention\n\nTraditional sequence models like Recurrent Neural Networks (RNNs) faced significant challenges with long-range dependencies. Their sequential processing inherently limited their ability to capture relationships between distant elements, often suffering from vanishing or exploding gradients. Convolutional Neural Networks (CNNs), while effective for some sequence tasks, primarily operate with fixed-size local receptive fields, making them less suitable for understanding global context across entire lengthy sequences without deep stacking.\n\nThe Transformer architecture emerged as a groundbreaking solution, revolutionizing sequence-to-sequence tasks, particularly in natural language processing. A key advantage of Transformers is their ability to process input sequences in parallel, a stark contrast to the inherently sequential nature of RNNs. This parallelization dramatically improved training efficiency and scalability.\n\nAt the heart of the Transformer's success lies its novel attention mechanism. This mechanism allows the model to weigh the importance of different parts of the input sequence when processing each element, effectively overcoming the sequential bottlenecks of RNNs. It enables the model to access global context directly, regardless of the distance between elements.\n\nThis foundational ability to selectively focus on relevant input parts is primarily driven by Self-Attention. Understanding Self-Attention is crucial to grasping how Transformers achieve their remarkable performance in tasks requiring sophisticated contextual understanding."),
#   (2,
#    '## The Intuition Behind Self-Attention\n\nImagine reading a sentence: as humans, we instinctively "pay attention" to specific words to understand the full context. For instance, when we encounter a pronoun, our brain quickly links it back to the noun it refers to. This ability to focus on relevant information is crucial for comprehension.\n\nConsider the sentence: "The animal didn\'t cross the street because **it** was too tired." To understand what "it" refers to, your mind naturally emphasizes "animal" from earlier in the sentence. This selective attention allows you to correctly interpret that the animal, not the street, was tired.\n\nSelf-attention brings this human-like intuition to models. For each word in an input sequence, the mechanism generates three conceptual vectors: a **Query (Q)**, a **Key (K)**, and a **Value (V)**. Think of the Query as what a word is "looking for," the Key as what a word "can offer," and the Value as the actual information a word carries.\n\nThe process unfolds as follows: for every word, its Query vector is compared against the Key vectors of *all* other words (including itself) in the sequence. This comparison yields "attention scores," indicating how relevant each word is to the current word. These scores are then used to create a weighted sum of the Value vectors from all words. This weighted sum becomes the new representation for the original word, now enriched with context from the most relevant parts of the sequence.'),
#   (3,
#    '## Mathematical Formulation of Scaled Dot-Product Self-Attention\n\nThe Scaled Dot-Product Self-Attention mechanism operates through a series of matrix operations. It begins by transforming the input embeddings into three distinct matrices: Query (Q), Key (K), and Value (V). For an input matrix `X` (where each row represents an embedding), these are generated by multiplying `X` with three learned weight matrices: `W_Q`, `W_K`, and `W_V`.\n\n`Q = X W_Q`\n`K = X W_K`\n`V = X W_V`\n\nHere, `Q` contains "queries" for information, `K` represents "keys" to match queries against, and `V` holds the actual information to be aggregated.\n\nNext, raw attention scores are calculated by computing the dot product between the Query matrix (`Q`) and the transpose of the Key matrix (`Kᵀ`). This operation, `Scores = QKᵀ`, measures the similarity or relevance of each query to every key, producing a matrix where each element `(i, j)` indicates how much the `i`-th query relates to the `j`-th key.\n\nTo prevent vanishing or exploding gradients during training, these raw scores are then divided by a scaling factor: the square root of the dimension of the key vectors (`√d_k`). This scaling is crucial because large `d_k` values can lead to very large dot products, which can push the softmax function into regions with tiny gradients. Dividing by `√d_k` mitigates this issue, ensuring a more stable gradient flow.\n\nAfter scaling, the softmax function is applied to each row of the scaled scores matrix. This normalizes the attention scores into a probability distribution, ensuring that all attention weights for a given query sum to 1. This transforms the relevance scores into interpretable weights, indicating the proportional importance of each input element to the current output element.\n\nFinally, the output of the attention head is computed by multiplying these softmax-normalized attention weights with the Value matrix (`V`). This operation, `Output = Attention Weights * V`, produces a weighted sum of the values, where the weights determine how much each original input value contributes to the final output representation.'),
#   (4,
#    '## Implementing Scaled Dot-Product Self-Attention (Minimal Working Example)\n\nTo solidify your understanding of how Scaled Dot-Product Self-Attention operates, let\'s walk through a minimal, runnable implementation using PyTorch. This example will demonstrate the core calculations involved in a single attention head, from input transformation to the final attention output.\n\nFirst, we begin by defining an input tensor `x`. This tensor represents a batch of sequences, where each sequence contains multiple tokens, and each token is represented by a `model_dim`-dimensional embedding. For instance, `x` could have a shape like `(batch_size, sequence_length, model_dim)`. From this input, we need to derive three distinct representations: Query (Q), Key (K), and Value (V). These are typically obtained through separate linear transformations (matrix multiplications) of the input tensor. Each linear layer projects the `model_dim` input features down to `d_k` dimensions for Q and K, and similarly for V (often `d_v`, but for simplicity, we\'ll use `d_k` here). These projections allow the model to learn different aspects of the input for querying, matching, and extracting information.\n\nNext, the core of the attention mechanism involves calculating the raw "attention scores." This is achieved by performing a dot product between the Query tensor and the transpose of the Key tensor (`Q @ Kᵀ`). The result is a matrix where each element `(i, j)` indicates how much token `i` (from Q) "attends" to token `j` (from K). To stabilize training and prevent the dot products from growing too large (especially with high `d_k`), these scores are then scaled by dividing them by the square root of `d_k`. This scaling factor helps maintain a consistent variance for the attention scores.\n\nFollowing the scaling, we apply a softmax function to these scaled attention scores. The softmax is typically applied along the last dimension (the sequence length dimension of the Key tensor). This operation normalizes the scores into a probability distribution, ensuring that the attention weights for each query vector sum to one. These "attention weights" quantify the relevance of each input token (from K) to the current query token (from Q). High weights indicate a strong focus on particular input tokens.\n\nFinally, to produce the output of the self-attention mechanism, we perform another matrix multiplication. The attention weights (which now represent how much each query should "attend" to each value) are multiplied by the Value (V) tensor. This operation effectively creates a weighted sum of the Value vectors, where the weights are determined by the attention scores. The resulting output tensor combines information from all input tokens, weighted according to their relevance to each position in the sequence, thus capturing contextual dependencies.\n\nBelow is a complete PyTorch code snippet demonstrating these steps with a sample input and printing the shapes at each stage for verification.\n\n```python\nimport torch\nimport torch.nn as nn\nimport math\n\n# For reproducibility\ntorch.manual_seed(0)\n\n# 1. Define input tensor and parameters\nbatch_size = 2\nseq_len = 5\nmodel_dim = 8  # Feature dimension of input token embeddings\nd_k = 4        # Dimension of Query, Key, Value vectors for a single head\n\n# Example input tensor: (batch_size, seq_len, model_dim)\n# Represents 2 sequences, each with 5 tokens, where each token has 8 features.\nx = torch.randn(batch_size, seq_len, model_dim)\n\n# Linear projections for Q, K, V.\n# In a full Transformer, these would be `nn.Linear` layers with learned weights.\n# For this example, we initialize simple linear transformations.\nquery_proj = nn.Linear(model_dim, d_k)\nkey_proj = nn.Linear(model_dim, d_k)\nvalue_proj = nn.Linear(model_dim, d_k)\n\n# Apply linear projections to get Q, K, V tensors\nQ = query_proj(x)  # (batch_size, seq_len, d_k)\nK = key_proj(x)    # (batch_size, seq_len, d_k)\nV = value_proj(x)  # (ba ...
#   (5,
#    '## Multi-Head Attention for Enhanced Representation\n\nA single self-attention head computes one set of attention weights, inherently limiting its focus to a single type of relationship or aspect within the input sequence. For example, it might prioritize syntactic dependencies while overlooking semantic similarities. This singular focus can restrict the model\'s ability to form a comprehensive understanding, potentially missing crucial contextual nuances.\n\nMulti-Head Attention addresses this by linearly projecting the input query (Q), key (K), and value (V) matrices *h* times into different, lower-dimensional subspaces. This creates *h* distinct sets of Q, K, and V. Each of these *h* "heads" then independently performs its own scaled dot-product self-attention calculation in parallel.\n\nOnce each attention head computes its output, these individual outputs are concatenated along the feature dimension. This combined matrix, which now holds diverse perspectives, then undergoes a final linear projection. This projection transforms the combined output back into the expected dimensionality, effectively merging the information from all heads into a single, unified representation.\n\nThe core benefit is enabling the model to jointly attend to information from different representation subspaces and positions. Each head can specialize in capturing distinct relationship types—e.g., long-range dependencies, local structures, or semantic links. By combining these varied insights, Multi-Head Attention significantly enriches the model\'s understanding of the input, leading to more robust and nuanced representations.'),
#   (6,
#    '## The Role of Positional Encoding\n\nPure Self-Attention, at its core, processes sequences as unordered sets of tokens. This characteristic makes it **permutation-invariant**: if you shuffle the input words, the attention mechanism itself will produce the same output values, just in a different order, without any intrinsic knowledge of their original sequence.\n\nHowever, for tasks involving natural language, sequence order is absolutely vital. The meaning and grammatical structure of a sentence are profoundly dependent on the arrangement of words. For instance, "dog bites man" conveys a very different meaning from "man bites dog," purely due to the change in word order. Without this information, a model cannot differentiate between such critical semantic distinctions.\n\nTo address this limitation, **Positional Encoding** is introduced. This mechanism injects information about the absolute or relative position of each token within the sequence directly into the input embeddings. By doing so, it provides the Transformer model with the necessary context regarding the order of words.\n\nCommon positional encoding schemes include sinusoidal functions, which generate unique patterns for each position. These positional encodings are then simply **added** to the corresponding token embeddings. This combined embedding (token embedding + positional encoding) is what then feeds into the subsequent Self-Attention layers, allowing the model to leverage positional information throughout its processing.'),
#   (7,
#    '## Computational Complexity and Performance Considerations\n\nSelf-Attention, while powerful, introduces significant computational and memory overheads, particularly with long input sequences. Understanding these complexities is crucial for designing efficient Transformer models.\n\nThe **time complexity** of Scaled Dot-Product Self-Attention is predominantly quadratic with respect to the sequence length, denoted as $O(N^2 \\cdot d)$. Here, $N$ represents the sequence length (number of tokens), and $d$ is the embedding dimension. This quadratic relationship arises from the core operation of computing attention scores: each query vector must be dotted with every key vector, resulting in an $N \\times N$ attention matrix. Subsequent matrix multiplications to scale and apply these weights to the value vectors also contribute to this $N^2$ factor, with the $d$ factor coming from the dimension of these vectors.\n\nFor **memory complexity**, the primary bottleneck is storing the attention matrix itself, which requires $O(N^2)$ memory. For a sequence of $N$ tokens, this matrix grows rapidly. For example, a sequence of 1,000 tokens would require 1 million entries for the attention matrix, which can quickly consume available GPU memory as $N$ increases, especially when considering multiple attention heads and layers within a full Transformer model.\n\nThese quadratic scaling characteristics have significant **practical implications**. Increased training time is a direct consequence, as computations grow exponentially with sequence length. More critically, the $O(N^2)$ memory requirement often becomes the limiting factor, dictating the maximum sequence length that can be processed on a given hardware setup. This constraint restricts models from handling very long documents or high-resolution media directly without chunking.\n\nTo mitigate these performance challenges for longer sequences, ongoing research explores **alternative attention mechanisms**. Approaches like sparse attention, which only computes attention over a subset of key-value pairs, or linear attention, which reduces complexity to $O(N \\cdot d)$, aim to overcome the quadratic barrier. Specific architectures such as BigBird and Longformer implement variants of sparse attention to enable processing of significantly longer contexts.'),
#   (1,
#    "## Introduction to Transformers and the Need for Attention\n\nTraditional sequence models like Recurrent Neural Networks (RNNs) faced significant challenges with long-range dependencies. Their sequential processing inherently limited their ability to capture relationships between distant elements, often suffering from vanishing or exploding gradients. Convolutional Neural Networks (CNNs), while effective for some sequence tasks, primarily operate with fixed-size local receptive fields, making them less suitable for understanding global context across entire lengthy sequences without deep stacking.\n\nThe Transformer architecture emerged as a groundbreaking solution, revolutionizing sequence-to-sequence tasks, particularly in natural language processing. A key advantage of Transformers is their ability to process input sequences in parallel, a stark contrast to the inherently sequential nature of RNNs. This parallelization dramatically improved training efficiency and scalability.\n\nAt the heart of the Transformer's success lies its novel attention mechanism. This mechanism allows the model to weigh the importance of different parts of the input sequence when processing each element, effectively overcoming the sequential bottlenecks of RNNs. It enables the model to access global context directly, regardless of the distance between elements.\n\nThis foundational ability to selectively focus on relevant input parts is primarily driven by Self-Attention. Understanding Self-Attention is crucial to grasping how Transformers achieve their remarkable performance in tasks requiring sophisticated contextual understanding."),
#   (2,
#    '## The Intuition Behind Self-Attention\n\nImagine reading a sentence: as humans, we instinctively "pay attention" to specific words to understand the full context. For instance, when we encounter a pronoun, our brain quickly links it back to the noun it refers to. This ability to focus on relevant information is crucial for comprehension.\n\nConsider the sentence: "The animal didn\'t cross the street because **it** was too tired." To understand what "it" refers to, your mind naturally emphasizes "animal" from earlier in the sentence. This selective attention allows you to correctly interpret that the animal, not the street, was tired.\n\nSelf-attention brings this human-like intuition to models. For each word in an input sequence, the mechanism generates three conceptual vectors: a **Query (Q)**, a **Key (K)**, and a **Value (V)**. Think of the Query as what a word is "looking for," the Key as what a word "can offer," and the Value as the actual information a word carries.\n\nThe process unfolds as follows: for every word, its Query vector is compared against the Key vectors of *all* other words (including itself) in the sequence. This comparison yields "attention scores," indicating how relevant each word is to the current word. These scores are then used to create a weighted sum of the Value vectors from all words. This weighted sum becomes the new representation for the original word, now enriched with context from the most relevant parts of the sequence.'),
#   (3,
#    '## Mathematical Formulation of Scaled Dot-Product Self-Attention\n\nThe Scaled Dot-Product Self-Attention mechanism operates through a series of matrix operations. It begins by transforming the input embeddings into three distinct matrices: Query (Q), Key (K), and Value (V). For an input matrix `X` (where each row represents an embedding), these are generated by multiplying `X` with three learned weight matrices: `W_Q`, `W_K`, and `W_V`.\n\n`Q = X W_Q`\n`K = X W_K`\n`V = X W_V`\n\nHere, `Q` contains "queries" for information, `K` represents "keys" to match queries against, and `V` holds the actual information to be aggregated.\n\nNext, raw attention scores are calculated by computing the dot product between the Query matrix (`Q`) and the transpose of the Key matrix (`Kᵀ`). This operation, `Scores = QKᵀ`, measures the similarity or relevance of each query to every key, producing a matrix where each element `(i, j)` indicates how much the `i`-th query relates to the `j`-th key.\n\nTo prevent vanishing or exploding gradients during training, these raw scores are then divided by a scaling factor: the square root of the dimension of the key vectors (`√d_k`). This scaling is crucial because large `d_k` values can lead to very large dot products, which can push the softmax function into regions with tiny gradients. Dividing by `√d_k` mitigates this issue, ensuring a more stable gradient flow.\n\nAfter scaling, the softmax function is applied to each row of the scaled scores matrix. This normalizes the attention scores into a probability distribution, ensuring that all attention weights for a given query sum to 1. This transforms the relevance scores into interpretable weights, indicating the proportional importance of each input element to the current output element.\n\nFinally, the output of the attention head is computed by multiplying these softmax-normalized attention weights with the Value matrix (`V`). This operation, `Output = Attention Weights * V`, produces a weighted sum of the values, where the weights determine how much each original input value contributes to the final output representation.'),
#   (4,
#    '## Implementing Scaled Dot-Product Self-Attention (Minimal Working Example)\n\nTo solidify your understanding of how Scaled Dot-Product Self-Attention operates, let\'s walk through a minimal, runnable implementation using PyTorch. This example will demonstrate the core calculations involved in a single attention head, from input transformation to the final attention output.\n\nFirst, we begin by defining an input tensor `x`. This tensor represents a batch of sequences, where each sequence contains multiple tokens, and each token is represented by a `model_dim`-dimensional embedding. For instance, `x` could have a shape like `(batch_size, sequence_length, model_dim)`. From this input, we need to derive three distinct representations: Query (Q), Key (K), and Value (V). These are typically obtained through separate linear transformations (matrix multiplications) of the input tensor. Each linear layer projects the `model_dim` input features down to `d_k` dimensions for Q and K, and similarly for V (often `d_v`, but for simplicity, we\'ll use `d_k` here). These projections allow the model to learn different aspects of the input for querying, matching, and extracting information.\n\nNext, the core of the attention mechanism involves calculating the raw "attention scores." This is achieved by performing a dot product between the Query tensor and the transpose of the Key tensor (`Q @ Kᵀ`). The result is a matrix where each element `(i, j)` indicates how much token `i` (from Q) "attends" to token `j` (from K). To stabilize training and prevent the dot products from growing too large (especially with high `d_k`), these scores are then scaled by dividing them by the square root of `d_k`. This scaling factor helps maintain a consistent variance for the attention scores.\n\nFollowing the scaling, we apply a softmax function to these scaled attention scores. The softmax is typically applied along the last dimension (the sequence length dimension of the Key tensor). This operation normalizes the scores into a probability distribution, ensuring that the attention weights for each query vector sum to one. These "attention weights" quantify the relevance of each input token (from K) to the current query token (from Q). High weights indicate a strong focus on particular input tokens.\n\nFinally, to produce the output of the self-attention mechanism, we perform another matrix multiplication. The attention weights (which now represent how much each query should "attend" to each value) are multiplied by the Value (V) tensor. This operation effectively creates a weighted sum of the Value vectors, where the weights are determined by the attention scores. The resulting output tensor combines information from all input tokens, weighted according to their relevance to each position in the sequence, thus capturing contextual dependencies.\n\nBelow is a complete PyTorch code snippet demonstrating these steps with a sample input and printing the shapes at each stage for verification.\n\n```python\nimport torch\nimport torch.nn as nn\nimport math\n\n# For reproducibility\ntorch.manual_seed(0)\n\n# 1. Define input tensor and parameters\nbatch_size = 2\nseq_len = 5\nmodel_dim = 8  # Feature dimension of input token embeddings\nd_k = 4        # Dimension of Query, Key, Value vectors for a single head\n\n# Example input tensor: (batch_size, seq_len, model_dim)\n# Represents 2 sequences, each with 5 tokens, where each token has 8 features.\nx = torch.randn(batch_size, seq_len, model_dim)\n\n# Linear projections for Q, K, V.\n# In a full Transformer, these would be `nn.Linear` layers with learned weights.\n# For this example, we initialize simple linear transformations.\nquery_proj = nn.Linear(model_dim, d_k)\nkey_proj = nn.Linear(model_dim, d_k)\nvalue_proj = nn.Linear(model_dim, d_k)\n\n# Apply linear projections to get Q, K, V tensors\nQ = query_proj(x)  # (batch_size, seq_len, d_k)\nK = key_proj(x)    # (batch_size, seq_len, d_k)\nV = value_proj(x)  # (ba ...
#   (5,
#    '## Multi-Head Attention for Enhanced Representation\n\nA single self-attention head computes one set of attention weights, inherently limiting its focus to a single type of relationship or aspect within the input sequence. For example, it might prioritize syntactic dependencies while overlooking semantic similarities. This singular focus can restrict the model\'s ability to form a comprehensive understanding, potentially missing crucial contextual nuances.\n\nMulti-Head Attention addresses this by linearly projecting the input query (Q), key (K), and value (V) matrices *h* times into different, lower-dimensional subspaces. This creates *h* distinct sets of Q, K, and V. Each of these *h* "heads" then independently performs its own scaled dot-product self-attention calculation in parallel.\n\nOnce each attention head computes its output, these individual outputs are concatenated along the feature dimension. This combined matrix, which now holds diverse perspectives, then undergoes a final linear projection. This projection transforms the combined output back into the expected dimensionality, effectively merging the information from all heads into a single, unified representation.\n\nThe core benefit is enabling the model to jointly attend to information from different representation subspaces and positions. Each head can specialize in capturing distinct relationship types—e.g., long-range dependencies, local structures, or semantic links. By combining these varied insights, Multi-Head Attention significantly enriches the model\'s understanding of the input, leading to more robust and nuanced representations.'),
#   (6,
#    '## The Role of Positional Encoding\n\nPure Self-Attention, at its core, processes sequences as unordered sets of tokens. This characteristic makes it **permutation-invariant**: if you shuffle the input words, the attention mechanism itself will produce the same output values, just in a different order, without any intrinsic knowledge of their original sequence.\n\nHowever, for tasks involving natural language, sequence order is absolutely vital. The meaning and grammatical structure of a sentence are profoundly dependent on the arrangement of words. For instance, "dog bites man" conveys a very different meaning from "man bites dog," purely due to the change in word order. Without this information, a model cannot differentiate between such critical semantic distinctions.\n\nTo address this limitation, **Positional Encoding** is introduced. This mechanism injects information about the absolute or relative position of each token within the sequence directly into the input embeddings. By doing so, it provides the Transformer model with the necessary context regarding the order of words.\n\nCommon positional encoding schemes include sinusoidal functions, which generate unique patterns for each position. These positional encodings are then simply **added** to the corresponding token embeddings. This combined embedding (token embedding + positional encoding) is what then feeds into the subsequent Self-Attention layers, allowing the model to leverage positional information throughout its processing.'),
#   (7,
#    '## Computational Complexity and Performance Considerations\n\nSelf-Attention, while powerful, introduces significant computational and memory overheads, particularly with long input sequences. Understanding these complexities is crucial for designing efficient Transformer models.\n\nThe **time complexity** of Scaled Dot-Product Self-Attention is predominantly quadratic with respect to the sequence length, denoted as $O(N^2 \\cdot d)$. Here, $N$ represents the sequence length (number of tokens), and $d$ is the embedding dimension. This quadratic relationship arises from the core operation of computing attention scores: each query vector must be dotted with every key vector, resulting in an $N \\times N$ attention matrix. Subsequent matrix multiplications to scale and apply these weights to the value vectors also contribute to this $N^2$ factor, with the $d$ factor coming from the dimension of these vectors.\n\nFor **memory complexity**, the primary bottleneck is storing the attention matrix itself, which requires $O(N^2)$ memory. For a sequence of $N$ tokens, this matrix grows rapidly. For example, a sequence of 1,000 tokens would require 1 million entries for the attention matrix, which can quickly consume available GPU memory as $N$ increases, especially when considering multiple attention heads and layers within a full Transformer model.\n\nThese quadratic scaling characteristics have significant **practical implications**. Increased training time is a direct consequence, as computations grow exponentially with sequence length. More critically, the $O(N^2)$ memory requirement often becomes the limiting factor, dictating the maximum sequence length that can be processed on a given hardware setup. This constraint restricts models from handling very long documents or high-resolution media directly without chunking.\n\nTo mitigate these performance challenges for longer sequences, ongoing research explores **alternative attention mechanisms**. Approaches like sparse attention, which only computes attention over a subset of key-value pairs, or linear attention, which reduces complexity to $O(N \\cdot d)$, aim to overcome the quadratic barrier. Specific architectures such as BigBird and Longformer implement variants of sparse attention to enable processing of significantly longer contexts.')],
#  'merged_md': '# Unpacking Self-Attention: The Core Mechanism of Transformer Architectures\n\n## Introduction to Transformers and the Need for Attention\n\nTraditional sequence models like Recurrent Neural Networks (RNNs) faced significant challenges with long-range dependencies. Their sequential processing inherently limited their ability to capture relationships between distant elements, often suffering from vanishing or exploding gradients. Convolutional Neural Networks (CNNs), while effective for some sequence tasks, primarily operate with fixed-size local receptive fields, making them less suitable for understanding global context across entire lengthy sequences without deep stacking.\n\nThe Transformer architecture emerged as a groundbreaking solution, revolutionizing sequence-to-sequence tasks, particularly in natural language processing. A key advantage of Transformers is their ability to process input sequences in parallel, a stark contrast to the inherently sequential nature of RNNs. This parallelization dramatically improved training efficiency and scalability.\n\nAt the heart of the Transformer\'s success lies its novel attention mechanism. This mechanism allows the model to weigh the importance of different parts of the input sequence when processing each element, effectively overcoming the sequential bottlenecks of RNNs. It enables the model to access global context directly, regardless of the distance between elements.\n\nThis foundational ability to selectively focus on relevant input parts is primarily driven by Self-Attention. Understanding Self-Attention is crucial to grasping how Transformers achieve their remarkable performance in tasks requiring sophisticated contextual understanding.\n\n## The Intuition Behind Self-Attention\n\nImagine reading a sentence: as humans, we instinctively "pay attention" to specific words to understand the full context. For instance, when we encounter a pronoun, our brain quickly links it back to the noun it refers to. This ability to focus on relevant information is crucial for comprehension.\n\nConsider the sentence: "The animal didn\'t cross the street because **it** was too tired." To understand what "it" refers to, your mind naturally emphasizes "animal" from earlier in the sentence. This selective attention allows you to correctly interpret that the animal, not the street, was tired.\n\nSelf-attention brings this human-like intuition to models. For each word in an input sequence, the mechanism generates three conceptual vectors: a **Query (Q)**, a **Key (K)**, and a **Value (V)**. Think of the Query as what a word is "looking for," the Key as what a word "can offer," and the Value as the actual information a word carries.\n\nThe process unfolds as follows: for every word, its Query vector is compared against the Key vectors of *all* other words (including itself) in the sequence. This comparison yields "attention scores," indicating how relevant each word is to the current word. These scores are then used to create a weighted sum of the Value vectors from all words. This weighted sum becomes the new representation for the original word, now enriched with context from the most relevant parts of the sequence.\n\n## Mathematical Formulation of Scaled Dot-Product Self-Attention\n\nThe Scaled Dot-Product Self-Attention mechanism operates through a series of matrix operations. It begins by transforming the input embeddings into three distinct matrices: Query (Q), Key (K), and Value (V). For an input matrix `X` (where each row represents an embedding), these are generated by multiplying `X` with three learned weight matrices: `W_Q`, `W_K`, and `W_V`.\n\n`Q = X W_Q`\n`K = X W_K`\n`V = X W_V`\n\nHere, `Q` contains "queries" for information, `K` represents "keys" to match queries against, and `V` holds the actual information to be aggregated.\n\nNext, raw attention scores are calculated by computing the dot product between the Query matrix (`Q`) and the transpose of the Key matrix ...
#  'md_with_placeholders': '# Unpacking Self-Attention: The Core Mechanism of Transformer Architectures\n\n## Introduction to Transformers and the Need for Attention\n\nTraditional sequence models like Recurrent Neural Networks (RNNs) faced significant challenges with long-range dependencies. Their sequential processing inherently limited their ability to capture relationships between distant elements, often suffering from vanishing or exploding gradients. Convolutional Neural Networks (CNNs), while effective for some sequence tasks, primarily operate with fixed-size local receptive fields, making them less suitable for understanding global context across entire lengthy sequences without deep stacking.\n\nThe Transformer architecture emerged as a groundbreaking solution, revolutionizing sequence-to-sequence tasks, particularly in natural language processing. A key advantage of Transformers is their ability to process input sequences in parallel, a stark contrast to the inherently sequential nature of RNNs. This parallelization dramatically improved training efficiency and scalability.\n\nAt the heart of the Transformer\'s success lies its novel attention mechanism. This mechanism allows the model to weigh the importance of different parts of the input sequence when processing each element, effectively overcoming the sequential bottlenecks of RNNs. It enables the model to access global context directly, regardless of the distance between elements.\n\nThis foundational ability to selectively focus on relevant input parts is primarily driven by Self-Attention. Understanding Self-Attention is crucial to grasping how Transformers achieve their remarkable performance in tasks requiring sophisticated contextual understanding.\n\n## The Intuition Behind Self-Attention\n\nImagine reading a sentence: as humans, we instinctively "pay attention" to specific words to understand the full context. For instance, when we encounter a pronoun, our brain quickly links it back to the noun it refers to. This ability to focus on relevant information is crucial for comprehension.\n\nConsider the sentence: "The animal didn\'t cross the street because **it** was too tired." To understand what "it" refers to, your mind naturally emphasizes "animal" from earlier in the sentence. This selective attention allows you to correctly interpret that the animal, not the street, was tired.\n\nSelf-attention brings this human-like intuition to models. For each word in an input sequence, the mechanism generates three conceptual vectors: a **Query (Q)**, a **Key (K)**, and a **Value (V)**. Think of the Query as what a word is "looking for," the Key as what a word "can offer," and the Value as the actual information a word carries.\n\nThe process unfolds as follows: for every word, its Query vector is compared against the Key vectors of *all* other words (including itself) in the sequence. This comparison yields "attention scores," indicating how relevant each word is to the current word. These scores are then used to create a weighted sum of the Value vectors from all words. This weighted sum becomes the new representation for the original word, now enriched with context from the most relevant parts of the sequence.\n\n## Mathematical Formulation of Scaled Dot-Product Self-Attention\n\nThe Scaled Dot-Product Self-Attention mechanism operates through a series of matrix operations. It begins by transforming the input embeddings into three distinct matrices: Query (Q), Key (K), and Value (V). For an input matrix `X` (where each row represents an embedding), these are generated by multiplying `X` with three learned weight matrices: `W_Q`, `W_K`, and `W_V`.\n\n`Q = X W_Q`\n`K = X W_K`\n`V = X W_V`\n\nHere, `Q` contains "queries" for information, `K` represents "keys" to match queries against, and `V` holds the actual information to be aggregated.\n\nNext, raw attention scores are calculated by computing the dot product between the Query matrix (`Q`) and the transpose of the ...
#  'image_specs': [{'placeholder': '[[IMAGE_1]]',
#    'filename': 'scaled_dot_product_attention.png',
#    'alt': 'Diagram showing the flow of Scaled Dot-Product Self-Attention, from input embeddings to Q, K, V, dot product, scaling, softmax, and weighted sum of V.',
#    'caption': 'Flowchart of the Scaled Dot-Product Self-Attention mechanism, detailing the mathematical operations from input embeddings to the final contextualized output.',
#    'prompt': "A clear, concise technical diagram illustrating the Scaled Dot-Product Self-Attention mechanism. Show input embedding 'X' leading to linear transformations for 'Query (Q)', 'Key (K)', and 'Value (V)'. Then, depict the dot product of Q and K transpose, followed by scaling by 'sqrt(dk)', applying softmax, and finally multiplying by V to produce the output. Use arrows for flow and clear labels for each step and matrix operation.",
#    'size': '1536x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_2]]',
#    'filename': 'multi_head_attention.png',
#    'alt': 'Diagram illustrating the Multi-Head Attention process, showing parallel attention heads, concatenation of their outputs, and a final linear projection.',
#    'caption': 'The Multi-Head Attention mechanism allows the model to capture diverse relationships by processing information through multiple attention heads in parallel, then concatenating and projecting their outputs.',
#    'prompt': "A technical diagram illustrating the Multi-Head Attention mechanism. Show an input 'X' being linearly projected multiple times (e.g., 'h' times) to create different Q, K, V for each 'attention head'. Depict each head performing independent scaled dot-product self-attention in parallel. Then, show the concatenation of the outputs from all heads, followed by a final linear projection to produce the overall Multi-Head Attention output. Use clear labels and arrows.",
#    'size': '1536x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_3]]',
#    'filename': 'positional_encoding.png',
#    'alt': "Diagram showing token embeddings being augmented with positional encodings through element-wise addition before being fed into the Transformer's attention layers.",
#    'caption': "Positional Encodings are added to token embeddings to inject sequence order information, which is crucial for the Transformer's understanding of language structure.",
#    'prompt': "A simple conceptual diagram showing how Positional Encoding works. Depict token embeddings (e.g., 'word 1 embedding', 'word 2 embedding') and separate 'positional encoding 1', 'positional encoding 2'. Show these two types of vectors being added element-wise to create a 'combined input embedding' that is then fed into the self-attention layer. Use clear labels and arrows.",
#    'size': '1024x1024',
#    'quality': 'medium'}],
#  'final': '# Unpacking Self-Attention: The Core Mechanism of Transformer Architectures\n\n## Introduction to Transformers and the Need for Attention\n\nTraditional sequence models like Recurrent Neural Networks (RNNs) faced significant challenges with long-range dependencies. Their sequential processing inherently limited their ability to capture relationships between distant elements, often suffering from vanishing or exploding gradients. Convolutional Neural Networks (CNNs), while effective for some sequence tasks, primarily operate with fixed-size local receptive fields, making them less suitable for understanding global context across entire lengthy sequences without deep stacking.\n\nThe Transformer architecture emerged as a groundbreaking solution, revolutionizing sequence-to-sequence tasks, particularly in natural language processing. A key advantage of Transformers is their ability to process input sequences in parallel, a stark contrast to the inherently sequential nature of RNNs. This parallelization dramatically improved training efficiency and scalability.\n\nAt the heart of the Transformer\'s success lies its novel attention mechanism. This mechanism allows the model to weigh the importance of different parts of the input sequence when processing each element, effectively overcoming the sequential bottlenecks of RNNs. It enables the model to access global context directly, regardless of the distance between elements.\n\nThis foundational ability to selectively focus on relevant input parts is primarily driven by Self-Attention. Understanding Self-Attention is crucial to grasping how Transformers achieve their remarkable performance in tasks requiring sophisticated contextual understanding.\n\n## The Intuition Behind Self-Attention\n\nImagine reading a sentence: as humans, we instinctively "pay attention" to specific words to understand the full context. For instance, when we encounter a pronoun, our brain quickly links it back to the noun it refers to. This ability to focus on relevant information is crucial for comprehension.\n\nConsider the sentence: "The animal didn\'t cross the street because **it** was too tired." To understand what "it" refers to, your mind naturally emphasizes "animal" from earlier in the sentence. This selective attention allows you to correctly interpret that the animal, not the street, was tired.\n\nSelf-attention brings this human-like intuition to models. For each word in an input sequence, the mechanism generates three conceptual vectors: a **Query (Q)**, a **Key (K)**, and a **Value (V)**. Think of the Query as what a word is "looking for," the Key as what a word "can offer," and the Value as the actual information a word carries.\n\nThe process unfolds as follows: for every word, its Query vector is compared against the Key vectors of *all* other words (including itself) in the sequence. This comparison yields "attention scores," indicating how relevant each word is to the current word. These scores are then used to create a weighted sum of the Value vectors from all words. This weighted sum becomes the new representation for the original word, now enriched with context from the most relevant parts of the sequence.\n\n## Mathematical Formulation of Scaled Dot-Product Self-Attention\n\nThe Scaled Dot-Product Self-Attention mechanism operates through a series of matrix operations. It begins by transforming the input embeddings into three distinct matrices: Query (Q), Key (K), and Value (V). For an input matrix `X` (where each row represents an embedding), these are generated by multiplying `X` with three learned weight matrices: `W_Q`, `W_K`, and `W_V`.\n\n`Q = X W_Q`\n`K = X W_K`\n`V = X W_V`\n\nHere, `Q` contains "queries" for information, `K` represents "keys" to match queries against, and `V` holds the actual information to be aggregated.\n\nNext, raw attention scores are calculated by computing the dot product between the Query matrix (`Q`) and the transpose of the Key matrix (`K ...
